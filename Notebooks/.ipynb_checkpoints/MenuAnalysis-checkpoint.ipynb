# %% [markdown]
# ## Using Pandas to Curate Data from the New York Public Library's *What's On the Menu?* Project
#
# Alok K. Shukla
#
# Aug 3, 2017

# %%
# By convention
import pandas as pd
import bisect

def justLesserThan2012(values):
    values.sort()
    index = bisect.bisect(values, "2012")
    return values[index-1]

def justGreaterThan1851(values):
    values.sort()
    index = bisect.bisect(values, "1850")
    return values[index]

# %%
print(justGreaterThan1851(["1","2","1851","1852","1854"]))
# Out:
# 1851

# %% [markdown]
# #### Loading Data
#
# For this I want to setup two DataFrames—one with the contents of Dish.csv (~25 MB in the latest download) and one with the contents of MenuItem.csv (~114 MB).
#
# As mentioned, Open Refine hangs before it can load MenuItem.csv (without increasing the Java heap size to provide more memory). So, though the timings will vary across systems, I've included time profiling information to show how speedily Pandas handles this job.

# %%
# %%time

dish_data = '../Cleaned Data/Dish/Dish-Clean.csv'
dish_df = pd.read_csv(dish_data, index_col='id',encoding='latin1')
# Out:
# CPU times: user 763 ms, sys: 105 ms, total: 868 ms
# Wall time: 874 ms

# %%
# %%time

menu_item_data = '../Dataset/MenuItem.csv'
item_df = pd.read_csv(menu_item_data, index_col='dish_id',encoding='latin1')
# Out:
# CPU times: user 3.65 s, sys: 429 ms, total: 4.08 s
# Wall time: 4.2 s
# /Users/alokkshukla/anaconda/lib/python3.6/site-packages/numpy/lib/arraysetops.py:395: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %% [markdown]
# We can make it easier to join up data by selecting the dish id (equal to the "primary key" of the first DataFrame) as the column to index by when loading up the second DataFrame.

# %% [markdown]
# With both DataFrames set up, we can print the first few rows to check that everything looks right.

# %%
dish_df[:5]
# Out:
#                           name  description  menus_appeared  times_appeared  \
# id
# 1   Consomme Printaniere Royal          NaN               8               8
# 2                Chicken Gumbo          NaN             111             117
# 3          Tomato Aux Croutons          NaN              13              13
# 4              Onion Au Gratin          NaN              41              41
# 5                   St Emilion          NaN              66              68
#
#    first_appeared  last_appeared  lowest_price  highest_price
# id
# 1            1897           1927          0.20            0.4
# 2            1895           1960          0.10            0.8
# 3            1893           1917          0.25            0.4
# 4            1900           1971          0.25            1.0
# 5            1881           1981          0.00           18.0

# %%
item_df.head(5)
# Out:
#          id  menu_page_id  price  high_price               created_at  \
# dish_id
# 1.0       1          1389    0.4         NaN  2011-03-28 15:00:44 UTC
# 2.0       2          1389    0.6         NaN  2011-03-28 15:01:13 UTC
# 3.0       3          1389    0.4         NaN  2011-03-28 15:01:40 UTC
# 4.0       4          1389    0.5         NaN  2011-03-28 15:01:51 UTC
# 5.0       5          3079    0.5         1.0  2011-03-28 15:21:26 UTC
#
#                       updated_at      xpos      ypos
# dish_id
# 1.0      2011-04-19 04:33:15 UTC  0.111429  0.254735
# 2.0      2011-04-19 15:00:54 UTC  0.438571  0.254735
# 3.0      2011-04-19 19:10:05 UTC  0.140000  0.261922
# 4.0      2011-04-19 19:07:01 UTC  0.377143  0.262720
# 5.0      2011-04-13 15:25:27 UTC  0.105714  0.313178

# %% [markdown]
# Pandas integrates with the Notebook to display DataFrames as nice HTML tables. It's also possible to print a summary description of a DataFrame.

# %%
dish_df
# Out:
#                                                  name  description  \
# id
# 1                          Consomme Printaniere Royal          NaN
# 14                   4               4           1899           1900
# 15                4246            4690              1           2928
# 16                 145             148           1897           1918
# 17                 505             534           1880           1987
# 18                1425            1484           1856           2928
# 19                  16              16           1865           1901
# 20                 453             472           1852           1987
# 21                  83              86           1851           1948
# 22                   9               9           1898           1901
# 23                  11              11           1880           1950
# 24                   2               2           1900           1900
# 25                   4               4           1900           1901
# 26                 170             180           1881           1970
# 27                 289             292           1862           1963
# 28                   2               2           1899           1900
# 29                  14              14           1895           1914
# 30                   1               1           1901           1901
# 31                 220             238           1900           1987
# ...                ...             ...            ...            ...
# 515648               1               1              0              0
# 515649               1               1              0              0
# 515650               1               1              0              0
# 515651               1               1              0              0
# 515652               1               1              0              0
# 515653               1               1              0              0
# 515654               1               1              0              0
# 515655               0               0              0              0
# 515656               1               1              0              0
# 515657               1               1              0              0
# 515658               1               1              0              0
# 515659               1               1              0              0
# 515660               1               1              0              0
# 515661               1               1              0              0
# 515662               1               1              0              0
# 515663               1               1              0              0
# 515664               1               1              0              0
# 515665               1               1              0              0
# 515666               1               1              0              0
# 515667               1               1              0              0
# 515668               1               1              0              0
# 515669               1               1              0              0
# 515670               1               1              0              0
# 515671               1               1              0              0
# 515672               1               1              0              0
# 515673               1               1              0              0
# 515674               1               1              0              0
# 515675               1               1              0              0
# 515676               1               1              0              0
# 515677               1               1              0              0
#
#         lowest_price  highest_price
# id
# 1               0.20           0.40
# 2               0.10           0.80
# 3               0.25           0.40
# 4               0.25           1.00
# 5               0.00          18.00
# 7               0.00          25.00
# 8               0.10           0.60
# 9               0.15           0.40
# 10              0.00           0.00
# 11              0.25          60.00
# 12              0.00           0.00
# 13              0.00          30.00
# 14              0.00           0.00
# 15              0.00          50.00
# 16              0.15          35.00
# 17              0.00          75.00
# 18              0.00          50.00
# 19              0.10           0.20
# 20              0.00          10.00
# 21              0.10           0.30
# 22              1.00           1.00
# 23              0.75           5.00
# 24              0.00           0.00
# 25              0.30           0.75
# 26              0.10           0.90
# 27              0.00          35.00
# 28              1.50           2.50
# 29              2.00           4.00
# 30              0.00           0.00
# 31              0.00          15.00
# ...              ...            ...
# 515648          0.00           0.00
# 515649          0.00           0.00
# 515650          0.00           0.00
# 515651          0.00           0.00
# 515652          0.00           0.00
# 515653          0.00           0.00
# 515654          0.00           0.00
# 515655          0.00           0.00
# 515656          0.00           0.00
# 515657          0.00           0.00
# 515658          0.00           0.00
# 515659          0.00           0.00
# 515660          0.00           0.00
# 515661          0.00           0.00
# 515662          0.00           0.00
# 515663          0.00           0.00
# 515664          0.00           0.00
# 515665          0.00           0.00
# 515666          0.00           0.00
# 515667          0.00           0.00
# 515668          0.00           0.00
# 515669          0.00           0.00
# 515670          0.00           0.00
# 515671          0.00           0.00
# 515672          0.00           0.00
# 515673          0.00           0.00
# 515674          0.00           0.00
# 515675          0.00           0.00
# 515676          0.00           0.00
# 515677          0.00           0.00
#
# [423397 rows x 8 columns]

# %% [markdown]
# #### Clustering to Find Duplicate Values
#
# For the moment, I'll focus on the Dish data.

# %% [markdown]
# With a single function call, we can see how many different values we have in the 'name' column before we start de-duping

# %%
unique_values_t0 = len(dish_df.name.unique())
print (unique_values_t0)
# Out:
# 304241

# %% [markdown]
# To start, almost all the values of dish name are supposedly unique

# %%
# Drop the 'description' column because it's empty and taking up screen real estate
del dish_df['description']

# %% [markdown]
# In order to find very similar values that we can identify as duplicates and normalize, I'll pursue the same series of steps I would take using Open Refine.

# %%
def strip_and_lower(x):
    """
    Basic string normalization:
    1) strip leading and trailing whitespace
    2) convert to lowercase
    3) normalize internal whitespace (remove extra spaces between tokens)
    """
    
    tokens = x.strip().lower().split()
    result = ' '.join(filter(None, tokens))
    
    return result

# Apply the function to every value of name using map() — rather than, for instance, using a loop
dish_df['name_modified'] = dish_df['name'].map(strip_and_lower)

# %% [markdown]
# A new column has been created:

# %%
dish_df[:5]
# Out:
#                           name  menus_appeared  times_appeared first_appeared  \
# id
# 1   Consomme Printaniere Royal               8               8           1897
# 2                Chicken Gumbo             111             117           1895
# 3          Tomato Aux Croutons              13              13           1893
# 4              Onion Au Gratin              41              41           1900
# 5                   St Emilion              66              68           1881
#
#     last_appeared  lowest_price  highest_price               name_modified
# id
# 1            1927          0.20            0.4  consomme printaniere royal
# 2            1960          0.10            0.8               chicken gumbo
# 3            1917          0.25            0.4         tomato aux croutons
# 4            1971          0.25            1.0             onion au gratin
# 5            1981          0.00           18.0                  st emilion

# %% [markdown]
# This already yields some duplicates which had been showing up as distinct values because of small (inconsequential) differences in whitespace or capitalization.

# %%
len(dish_df.name.unique())
# Out:
# 304241

# %% [markdown]
# Now, if we implement Open Refine-style clustering, we should find more candidates for de-duping.

# %%
import re

def fingerprint(x):
    """
    A modified version of the fingerprint clustering algorithm implemented by Open Refine.
    See https://github.com/OpenRefine/OpenRefine/wiki/Clustering-In-Depth
    This does not normalize to ASCII characters since diacritics may be significant in this dataset
    """
    alphanumeric_tokens = filter(None, re.split('\W', x))
    seen = set()
    seen_add = seen.add
    deduped = sorted([i for i in alphanumeric_tokens if i not in seen and not seen_add(i)])
    fingerprint = ''.join(deduped)
    
    return fingerprint

dish_df['fingerprint'] = dish_df['name_modified'].map(fingerprint)

# %% [markdown]
# We can see the results as another new column

# %%
top25 = dish_df.sort_values(['times_appeared'],ascending=False).head(25)
mostPopularrFingerprints = top25['fingerprint']
mostPopularrFingerprints
# Out:
# id
# 96                     cafe
# 97                      tea
# 15                   celeri
# 1177                 olives
# 7                  radishes
# 83           mashedpotatoes
# 98                     milk
# 219          boiledpotatoes
# 112                   fruit
# 217            chickensalad
# 4118        creamicevanilla
# 283                   cocoa
# 1049           lettucesalad
# 2474               applepie
# 795                  cheese
# 873             beansstring
# 231               chocolate
# 215            lobstersalad
# 18                 sardines
# 67              juiceorange
# 776             apollinaris
# 1308              roquefort
# 1259    frenchfriedpotatoes
# 1289         americancheese
# 408               greenpeas
# Name: fingerprint, dtype: object

# %% [markdown]
# To see the "clusters" of potential duplicate name values that the fingerprinting method identifies, we can group the data by the contents of the fingerprint column

# %%
clusters = dish_df.groupby('fingerprint')

# Order the clusters by size
s = clusters.size()
sorted_cluster_size = s.sort_values(ascending=False)

# %% [markdown]
# We might want to know what scope of variation there is in the size of the clusters. This can be accomplished with 1 line:,

# %%
value_counts = s.value_counts()

# %% [markdown]
# So, by this measure, there are still 294,118 singleton values (down from 399,421), but there are 23,204 two-item clusters that could be normalized, 110 11-item clusters, just 1 47-item cluster, etc.

# %% [markdown]
# The print display of the various clusters above shows only the fingerprint value and the count of rows that share that common value but this is not the most immediately-apprehensible way of seeing what's going on. For clarity, let's print the 5 largest clusters:

# %%
# Actually we'll be excluding the last item of the series since the value there is blank
#for f in s.sort_values()[-6:-1].index:
    #print(dish_df[dish_df.fingerprint == f].name)

# %% [markdown]
# At a glance these do indeed look like values that should be normalized to a single "name". Since the default way that IPython prints a Pandas Series object includes the 'id', it is easy to construct URLs to allow for some sanity checking.
#
# (I'm not automating the sanity checking here because I don't want to get in bad odor with NYPL's anti-spambot mechanisms.)

# %%
testing_cluster = dish_df[dish_df.fingerprint == 'mashedpotatoes']

for item in testing_cluster.index.tolist():
    url = "http://menus.nypl.org/dishes/{0}".format(item)
    #print(url)
top25['name']
# Out:
# id
# 96                       Cafe
# 97                        Tea
# 15                     Celeri
# 1177                   Olives
# 7                    Radishes
# 83            Mashed Potatoes
# 98                       Milk
# 219           Boiled Potatoes
# 112                     Fruit
# 217             Chicken Salad
# 4118        Vanilla Ice Cream
# 283                     Cocoa
# 1049            Lettuce Salad
# 2474                Apple Pie
# 795                    Cheese
# 873              String Beans
# 231                 Chocolate
# 215             Lobster Salad
# 18                   Sardines
# 67               Orange Juice
# 776               Apollinaris
# 1308                Roquefort
# 1259    French Fried Potatoes
# 1289          American Cheese
# 408                Green Peas
# Name: name, dtype: object

# %% [markdown]
# #### Better Dish Statistics

# %% [markdown]
# Identifying the clusters is great and we can use this information not only to improve the quality of the curated data set but also to clarify and improve analysis of the data about dish frequencies and "timespans." For the purposes of example, I'll use the "french fried potatoes" cluster.
#
# With 47 values to choose from, what should we select for a normalized value? How about the most common string already represented in the cluster?

# %%
result_df_list = []
for dish in mostPopularrFingerprints:
    #print(dish)
    
    result_df=(dish_df[dish_df.fingerprint == dish])
    result_df_list.append(result_df)

# Get the number of times appeared for each result by selecting that column (Series) and sort in descending order
    by_appearance = result_df.times_appeared.sort_values(ascending=False)

#Use the index of the max value to look up the most common value for the name
    print ("Most common value: '{0}'".format(dish_df.name[by_appearance.idxmax()]))
# Out:
# Most common value: 'Cafe'
# Most common value: 'Tea'
# Most common value: 'Celeri'
# Most common value: 'Olives'
# Most common value: 'Radishes'
# Most common value: 'Mashed Potatoes'
# Most common value: 'Milk'
# Most common value: 'Boiled Potatoes'
# Most common value: 'Fruit'
# Most common value: 'Chicken Salad'
# Most common value: 'Vanilla Ice Cream'
# Most common value: 'Cocoa'
# Most common value: 'Lettuce Salad'
# Most common value: 'Apple Pie'
# Most common value: 'Cheese'
# Most common value: 'String Beans'
# Most common value: 'Chocolate'
# Most common value: 'Lobster Salad'
# Most common value: 'Sardines'
# Most common value: 'Orange Juice'
# Most common value: 'Apollinaris'
# Most common value: 'Roquefort'
# Most common value: 'French Fried Potatoes'
# Most common value: 'American Cheese'
# Most common value: 'Green Peas'

# %% [markdown]
# Does clustering the values change the number of times a dish appeared or the earliest and latest dates it appears?

# %%
for df in result_df_list:
    print(df.times_appeared[:5])
# Out:
# id
# 96      8484
# 808      868
# 1255       5
# 1284       2
# 2450     885
# Name: times_appeared, dtype: int64
# id
# 97       4769
# 1260      390
# 1459       70
# 6397        5
# 13746       6
# Name: times_appeared, dtype: int64
# id
# 15       4690
# 5923      262
# 9475        1
# 11332      10
# 27113       2
# Name: times_appeared, dtype: int64
# id
# 1177      4553
# 11041        3
# 12530       15
# 21056        1
# 142297       1
# Name: times_appeared, dtype: int64
# id
# 7         3346
# 11053        8
# 43169        1
# 51872        1
# 111254       1
# Name: times_appeared, dtype: int64
# id
# 83       2670
# 2755      221
# 6382       61
# 9041       15
# 18871       1
# Name: times_appeared, dtype: int64
# id
# 98        2290
# 9200        27
# 21682       49
# 69646        1
# 137485       1
# Name: times_appeared, dtype: int64
# id
# 219      2129
# 2752      239
# 4290        6
# 17902       2
# 20308      81
# Name: times_appeared, dtype: int64
# id
# 112      2006
# 656        38
# 2246       63
# 8015        2
# 16317      23
# Name: times_appeared, dtype: int64
# id
# 217      1879
# 4881       57
# 13723       8
# 28474       3
# 29433       2
# Name: times_appeared, dtype: int64
# id
# 4118     1853
# 12056      10
# 16020      85
# 16556       6
# 26669       2
# Name: times_appeared, dtype: int64
# id
# 283     1704
# 1239       2
# 1250       3
# 2570     135
# 3922     368
# Name: times_appeared, dtype: int64
# id
# 1049     1680
# 10517       1
# 15229      91
# 18359       1
# 23194       8
# Name: times_appeared, dtype: int64
# id
# 2474     1618
# 4840       16
# 9048        6
# 39013       1
# 47779       2
# Name: times_appeared, dtype: int64
# id
# 795     1595
# 3164      33
# 3998      21
# 4436     280
# 4590      11
# Name: times_appeared, dtype: int64
# id
# 873      1570
# 49649       4
# 52150       1
# 59181       1
# 72932       1
# Name: times_appeared, dtype: int64
# id
# 231      1568
# 1252      146
# 10201       6
# 13017      49
# 24920       1
# Name: times_appeared, dtype: int64
# id
# 215      1566
# 4737       50
# 9044        7
# 18958       1
# 25606       1
# Name: times_appeared, dtype: int64
# id
# 18        1484
# 4533         4
# 12581        6
# 31817        2
# 138832       1
# Name: times_appeared, dtype: int64
# id
# 67       1479
# 5287      190
# 5729       12
# 9985       25
# 10250     637
# Name: times_appeared, dtype: int64
# id
# 179         4
# 776      1474
# 9144       73
# 14512       1
# 16246      37
# Name: times_appeared, dtype: int64
# id
# 1308     1447
# 8624        3
# 11435       1
# 11668      21
# 11880       3
# Name: times_appeared, dtype: int64
# id
# 1259     1409
# 2761      249
# 11893       1
# 14987      23
# 17047       3
# Name: times_appeared, dtype: int64
# id
# 1289     1398
# 15246      38
# 22892       5
# 25620       1
# 27172      15
# Name: times_appeared, dtype: int64
# id
# 408      1378
# 10422       5
# 28252      26
# 29681       1
# 69502       2
# Name: times_appeared, dtype: int64

# %% [markdown]
# According to this data (it varies slightly from what appears on [the web site](http://menus.nypl.org/dishes/1259)), the dish with id 1259 and name 'French fried potatoes' appears 1,392 times. Dish 2761 (name "Potatoes, French Fried") appears 243 times, etc.
#
# If we assert that all of these instances are in fact the same type of dish, we can quickly calculate a new total for how often this dish appears on the menus in the data set.

# %%
for df,dish in zip(result_df_list,top25['name']):
    total_appearances = df.times_appeared.sum()
    print (dish+" appeared {0} times in the menus digitized by NYPL.".format(total_appearances))
# Out:
# Cafe appear 11294 times in the menus digitized by NYPL.
# Tea appear 5522 times in the menus digitized by NYPL.
# Celeri appear 5513 times in the menus digitized by NYPL.
# Olives appear 4799 times in the menus digitized by NYPL.
# Radishes appear 3465 times in the menus digitized by NYPL.
# Mashed Potatoes appear 3468 times in the menus digitized by NYPL.
# Milk appear 2432 times in the menus digitized by NYPL.
# Boiled Potatoes appear 3043 times in the menus digitized by NYPL.
# Fruit appear 2238 times in the menus digitized by NYPL.
# Chicken Salad appear 2498 times in the menus digitized by NYPL.
# Vanilla Ice Cream appear 2639 times in the menus digitized by NYPL.
# Cocoa appear 2429 times in the menus digitized by NYPL.
# Lettuce Salad appear 2308 times in the menus digitized by NYPL.
# Apple Pie appear 1908 times in the menus digitized by NYPL.
# Cheese appear 2094 times in the menus digitized by NYPL.
# String Beans appear 1961 times in the menus digitized by NYPL.
# Chocolate appear 1833 times in the menus digitized by NYPL.
# Lobster Salad appear 2082 times in the menus digitized by NYPL.
# Sardines appear 1526 times in the menus digitized by NYPL.
# Orange Juice appear 2502 times in the menus digitized by NYPL.
# Apollinaris appear 1743 times in the menus digitized by NYPL.
# Roquefort appear 1558 times in the menus digitized by NYPL.
# French Fried Potatoes appear 2231 times in the menus digitized by NYPL.
# American Cheese appear 2037 times in the menus digitized by NYPL.
# Green Peas appear 2204 times in the menus digitized by NYPL.

# %% [markdown]
# We can do something similar for the date ranges. (It isn't even necessary to do anything with the data type of the values for first_appeared and last_appeared.)

# %%
for result_df,dish in zip(result_df_list,top25['name']):
    aggregate_first_appeared = justGreaterThan1851(result_df.first_appeared.tolist())
    aggregate_last_appeared = justLesserThan2012(result_df.last_appeared.tolist())
    print (dish+" first appeared on a menu in {0} and last appeared on a menu in {1}"\
    .format(aggregate_first_appeared, aggregate_last_appeared))
# Out:
# Cafe first appeared on a menu in 1866 and last appeared on a menu in 2928
# Tea first appeared on a menu in 1858 and last appeared on a menu in 2012
# Celeri first appeared on a menu in 1881 and last appeared on a menu in 2928
# Olives first appeared on a menu in 1858 and last appeared on a menu in 1987
# Radishes first appeared on a menu in 1854 and last appeared on a menu in 2928
# Mashed Potatoes first appeared on a menu in 1852 and last appeared on a menu in 2012
# Milk first appeared on a menu in 1890 and last appeared on a menu in 2012
# Boiled Potatoes first appeared on a menu in 1854 and last appeared on a menu in 1987
# Fruit first appeared on a menu in 1854 and last appeared on a menu in 2928
# Chicken Salad first appeared on a menu in 1858 and last appeared on a menu in 1987
# Vanilla Ice Cream first appeared on a menu in 1854 and last appeared on a menu in 2012
# Cocoa first appeared on a menu in 1851 and last appeared on a menu in 1998
# Lettuce Salad first appeared on a menu in 1865 and last appeared on a menu in 1974
# Apple Pie first appeared on a menu in 1851 and last appeared on a menu in 1987
# Cheese first appeared on a menu in 1851 and last appeared on a menu in 1990
# String Beans first appeared on a menu in 1858 and last appeared on a menu in 2928
# Chocolate first appeared on a menu in 1858 and last appeared on a menu in 1987
# Lobster Salad first appeared on a menu in 1858 and last appeared on a menu in 1995
# Sardines first appeared on a menu in 1856 and last appeared on a menu in 2928
# Orange Juice first appeared on a menu in 1851 and last appeared on a menu in 2012
# Apollinaris first appeared on a menu in 1884 and last appeared on a menu in 1988
# Roquefort first appeared on a menu in 1882 and last appeared on a menu in 1985
# French Fried Potatoes first appeared on a menu in 1884 and last appeared on a menu in 1989
# American Cheese first appeared on a menu in 1865 and last appeared on a menu in 2012
# Green Peas first appeared on a menu in 1854 and last appeared on a menu in 1985

# %% [markdown]
# For an apparently ever-popular dish like 'French fried potatoes' this 100-or-so year range is not that different from what appears on the page for the most-popular variant [(Dish 1259)](http://menus.nypl.org/dishes/1259). The aggregate values might shift more for other dishes.

# %% [markdown]
# Of course, there are also still 'pommes frites' to account for &hellip;

# %% [markdown]
# #### Plotting Results
#
# Reproducing NYPL's lovely appearance by year frequency plots takes a little more doing but it provides a good opportunity to demonstrate the facilities that Pandas provides for pulling together different sets of data using SQL-like mechanisms.

# %%
# Load data from the other CSV files included in the NYPL's regular data dumps because we'll need it all 
page_data = '../Dataset/MenuPage.csv'
page_df = pd.read_csv(page_data, index_col='id')

menu_data = '../Cleaned Data/Menu/Menu-Clean.csv'
menu_df = pd.read_csv(menu_data, index_col='id', parse_dates=True,encoding='latin1')

# %% [markdown]
# (For this final bit, I'm not entirely confident that I'm doing this in the best way. It seems to "work" but it feels a little verbose. Caveat lector.)

# %%
# This should create a DataFrame from the Menu Items data set that contains 
# only "rows" related to our example cluster of 'French fried potato' dishes
lookup_items_df = item_df[item_df.index.isin(result_df.index)]

# %%
# The length of this DataFrame should be same as the sum of occurrences we calculated above 
try:
    assert len(lookup_items_df) == result_df.times_appeared.sum()
    print ("Length of the DataFrame is consistent")
except:
    print ("Something's wrong")
# Out:
# Something's wrong

# %%
lookup_items_df.head(100)
# Out:
#              id  menu_page_id  price  high_price               created_at  \
# dish_id
# 83.0         90           154    NaN         NaN  2011-04-14 19:16:13 UTC
# 83.0        246          1349    NaN         NaN  2011-04-18 19:41:33 UTC
# 83.0        570           132    NaN         NaN  2011-04-19 16:50:37 UTC
# 83.0       1496           148    NaN         NaN  2011-04-19 19:48:39 UTC
# 83.0       2095           146    NaN         NaN  2011-04-19 22:21:36 UTC
# 83.0       2717           168   0.15         NaN  2011-04-20 01:46:12 UTC
# 2755.0     3959          3531   0.10         NaN  2011-04-20 05:25:00 UTC
# 83.0       5604          5654   0.10         NaN  2011-04-20 19:00:52 UTC
# 2755.0     5838          5006   0.10         NaN  2011-04-20 19:15:10 UTC
# 2755.0     6568          1321   0.15         NaN  2011-04-20 19:53:13 UTC
# 83.0       6700           302   0.10         NaN  2011-04-20 19:57:56 UTC
# 2755.0     7291          1341   0.10         0.2  2011-04-20 20:25:30 UTC
# 83.0       7456          2485   0.10         NaN  2011-04-20 20:34:56 UTC
# 2755.0     8032          2823   0.15         NaN  2011-04-20 21:02:35 UTC
# 83.0       8290         13733    NaN         NaN  2011-04-20 21:15:35 UTC
# 83.0       8856          6158    NaN         NaN  2011-04-20 21:51:40 UTC
# 9041.0    2011-04-21 20:49:28 UTC  0.550000  0.575685
# 83.0      2011-04-21 20:57:32 UTC  0.515714  0.324469
# 83.0      2011-04-21 20:59:06 UTC  0.274286  0.630936
# 83.0      2011-04-21 21:00:14 UTC  0.682857  0.632901
# 2755.0    2011-04-21 21:07:00 UTC  0.154286  0.803855
# 83.0      2011-07-12 18:37:32 UTC  0.221429  0.548123
# 83.0      2011-07-21 20:08:05 UTC  0.122857  0.578153
# 37872.0   2011-09-16 01:36:00 UTC  0.308571  0.481929
# 83.0      2011-04-21 21:21:33 UTC  0.150000  0.652176
# 83.0      2011-04-21 21:40:06 UTC  0.195714  0.543011
# 83.0      2011-04-21 21:42:32 UTC  0.208571  0.555219
# 83.0      2011-04-21 21:46:25 UTC  0.225714  0.578514
# 83.0      2011-04-21 21:50:42 UTC  0.240000  0.753336
# 83.0      2011-04-21 21:51:21 UTC  0.572857  0.350159
# 83.0      2011-04-21 22:30:02 UTC  0.152857  0.490237
# 375012.0  2013-07-31 16:10:42 UTC  0.608571  0.645712
# 83.0      2011-04-21 23:03:17 UTC  0.368571  0.611635
#
# [100 rows x 8 columns]

# %% [markdown]
# From this intermediate DataFrame we want to grab the values for menu_page_id so that we can look up the relevant menus to which they belong:

# %%
target_pages = lookup_items_df.menu_page_id.values

lookup_pages_df = page_df[page_df.index.isin(target_pages)]

# %%
lookup_pages_df.head(10)
# Out:
#      menu_id  page_number    image_id  full_height  full_width  \
# id
# 132    12464          1.0      466930       3679.0      2866.0
# 146    12470          1.0      466940       3427.0      2282.0
# 148    12471          1.0      466941       3454.0      2305.0
# 154    12473          1.0      466944       2293.0      1807.0
# 168    12475          1.0      466946       3929.0      2494.0
# 170    12476          3.0  4000009201       3813.0      2385.0
# 178    12479          3.0  4000009206       3511.0      2190.0
# 188    12483          1.0      466954       3920.0      2497.0
# 271    12508          1.0      475818       3108.0      2021.0
# 275    12510          1.0      475830       3661.0      2758.0
#
#                                      uuid
# id
# 132  510d47db-4921-a3d9-e040-e00a18064a99
# 146  510d47db-4933-a3d9-e040-e00a18064a99
# 148  510d47db-4935-a3d9-e040-e00a18064a99
# 154  510d47db-493d-a3d9-e040-e00a18064a99
# 168  510d47db-494b-a3d9-e040-e00a18064a99
# 170  510d47db-494d-a3d9-e040-e00a18064a99
# 178  510d47db-4955-a3d9-e040-e00a18064a99
# 188  510d47db-495f-a3d9-e040-e00a18064a99
# 271  510d47db-4311-a3d9-e040-e00a18064a99
# 275  510d47db-4315-a3d9-e040-e00a18064a99

# %% [markdown]
# Now we can grab all the relevant values of 'menu_id' for menus and do the last lookup:

# %%
target_menus = lookup_pages_df.menu_id.values

# %%
lookup_menus_df = menu_df[menu_df.index.isin(target_menus)]

# %% [markdown]
# Now we should have a DataFrame containing only menus that have pages on which one of the dishes from our 'French fried potato' cluster appears:

# %%
lookup_menus_df.head(10)
# Out:
#       name                                  sponsor  \
# id
# 12464  NaN                           REPUBLIC HOUSE
# 12470  NaN               NORDDEUTSCHER LLOYD BREMEN
# 12471  NaN               NORDDEUTSCHER LLOYD BREMEN
# 12473  NaN                        HOTEL MARLBOROUGH
# 12475  NaN                          HOTEL MANHATTAN
# 12476  NaN           PACIFIC MAIL STEAMSHIP COMPANY
# 12479  NaN  OCCIDENTAL & ORIENTAL STEAMSHIP COMPANY
# 12483  NaN                          HOTEL MANHATTAN
# 12508  NaN                   HOTEL MARIE ANTOINETTE
# 12510  NaN                   HOTEL MARIE ANTOINETTE
#
#                                  sponsor_clean                event  \
# id
# 12464                           REPUBLIC HOUSE               DINNER
# 12470               NORDDEUTSCHER LLOYD BREMEN  FRUHSTUCK-BREAKFAST
# 12471               NORDDEUTSCHER LLOYD BREMEN                LUNCH
# 12473                        HOTEL MARLBOROUGH        CAFE LUNCHEON
# 12475                          HOTEL MANHATTAN               DINNER
# 12476           PACIFIC MAIL STEAMSHIP COMPANY               DINNER
# 12479  OCCIDENTAL & ORIENTAL STEAMSHIP COMPANY               DINNER
# 12483                          HOTEL MANHATTAN        CARTE DU JOUR
# 12508                   HOTEL MARIE ANTOINETTE             LUNCHEON
# 12510                   HOTEL MARIE ANTOINETTE               DINNER
#
#             venue                                     place  \
# id
# 12464  COMMERCIAL                             MILWAUKEE, WI
# 12470  COMMERCIAL  SCHNELLDAMPFER DAISER WILHELM DER GROSSE
# 12471  COMMERCIAL         DAMPFER KAISER WILHELM DER GROSSE
# 12473  COMMERCIAL                              NEW YORK, NY
# 12475  COMMERCIAL                              NEW YORK, NY
# 12476  COMMERCIAL                           SS CITY OF PARA
# 12479  COMMERCIAL                                  SS DORIC
# 12483  COMMERCIAL                              NEW YORK, NY
# 12508  COMMERCIAL                        66TH ST. & BWAY NY
# 12510  COMMERCIAL                        66TH ST. & BWAY NY
#
#       physical_description_type physical_description 2  \
# id
# 12464                      CARD                  ILLUS
# 12470                 BROADSIDE                  ILLUS
# 12471                 BROADSIDE                  ILLUS
# 12473                      CARD                  ILLUS
# 12475                      CARD                  ILLUS
# 12476                    FOLDER                  ILLUS
# 12479                    FOLDER                  ILLUS
# 12483                      CARD                  ILLUS
# 12508                 BROADSIDE           HOTEL EMBLEM
# 12510                 BROADSIDE           HOTEL EMBLEM
#
#        physical_description_additional physical_description 3     ...      \
# id                                                                ...
# 12464          ILLUS -  COL -  7.0X9.0                    COL     ...
# 12470         ILLUS -  COL -  5.5X8.50                    COL     ...
# 12471         ILLUS -  COL -  5.5X8.50                    COL     ...
# 12473         ILLUS -  COL -  4.25X5.5                    COL     ...
# 12475                ILLUS -  6X9.5 -                   6X9.5     ...
# 12476               ILLUS -  6X9.25 -                  6X9.25     ...
# 12479              ILLUS -  5.5X8.5 -                 5.5X8.5     ...
# 12483                ILLUS -  6X9.5 -                   6X9.5     ...
# 12508     HOTEL EMBLEM -  4.5 X 7.5 -               4.5 X 7.5     ...
# 12510   HOTEL EMBLEM -  COL -  6.5 X 9                    COL     ...
#
#       language        date  date_clean  \
# id
# 12464      NaN  1900-04-15  1900-04-15
# 12470      NaN  1900-04-17  1900-04-17
# 12471      NaN  1900-04-17  1900-04-17
# 12473      NaN  1900-04-17  1900-04-17
# 12475      NaN  1900-04-18  1900-04-18
# 12476      NaN  1900-04-18  1900-04-18
# 12479      NaN  1900-04-18  1900-04-18
# 12483      NaN  1900-04-18  1900-04-18
# 12508      NaN  1900-02-19  1900-02-19
# 12510      NaN  1900-02-20  1900-02-20
#
#                                       location location_type currency  \
# id
# 12464                         REPUBLICAN HOUSE           NaN      NaN
# 12470                 NORDEUTCHER LLOYD BREMEN           NaN      NaN
# 12471                 NORDEUTCHER LLOYD BREMEN           NaN      NaN
# 12473                        HOTEL MARLBOROUGH           NaN      NaN
# 12475                          HOTEL MANHATTAN           NaN  DOLLARS
# 12476           PACIFIC MAIL STEAMSHIP COMPANY           NaN      NaN
# 12479  OCCIDENTAL & ORIENTAL STEAMSHIP COMPANY           NaN      NaN
# 12483                          HOTEL MANHATTAN           NaN  DOLLARS
# 12508                   HOTEL MARIE ANTOINETTE           NaN  DOLLARS
# 12510                   HOTEL MARIE ANTOINETTE           NaN  DOLLARS
#
#       currency_symbol        status  page_count  dish_count
# id
# 12464             NaN  under review           2          34
# 12470             NaN      complete           2          80
# 12471             NaN  under review           2          67
# 12473             NaN      complete           2          19
# 12475               $      complete           2         176
# 12476             NaN      complete           4          21
# 12479             NaN      complete           4          44
# 12483               $      complete           2         129
# 12508               $      complete           2          82
# 12510               $      complete           2         128
#
# [10 rows x 29 columns]

# %% [markdown]
# This next bit is a workaround since parsing the dates in the date column doesn't seem to be working for me as expected. I need to extract the year for each menu so I can group the number of appearances of dish by year

# %%
import dateutil

def extract_year(x):
    try:
        datestring = dateutil.parser.parse(x)
        return datestring.year
    except:
        return None

lookup_menus_df['date_year'] = lookup_menus_df['date'].map(extract_year)
# Out:
# /Users/alokkshukla/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# With a little IPython magic, it's possible to plot frequency of appearances:

# %%
# %matplotlib inline

by_year = lookup_menus_df.groupby(lookup_menus_df['date_year'])
year_series = by_year.size()
year_series.plot(figsize=(20,10))

# %% [markdown]
# Of course, this graph does not look right. What's going on with that huge spike at the beginning of the 20th century? And why do the number of appearances decrease toward mid-century?
#
# This skew is an artifact of the coverage of the underlying menu collection that NYPL holds. From the Library's own [collection guide](http://digitalgallery.nypl.org/nypldigital/explore/dgexplore.cfm?col_id=159):
# > Thousands of menus beginning with the oldest items in the collection from 1851. The collection is strongest for the period between 1890 and 1910.
#
# This is why NYPL, on their own site, has normalized the plot of dish appearances by total number of menus held for a given year.

# %%
# Extract years in the complete DataFrame for menus
menu_df['date_year'] = menu_df['date'].map(extract_year)

# Group by year and calculate the number of menus held for each year
total_menu_by_year = menu_df.groupby(menu_df['date_year'])
menu_total_series = total_menu_by_year.size()
#total_menu_by_year.head(10)

dish_df_by_year = dish_df.groupby(dish_df['first_appeared'])
dish_df_by_year.head(20)
# Out:
#                                                      name  menus_appeared  \
# id
# 1                              Consomme Printaniere Royal               8
# 2                                           Chicken Gumbo             111
# 3                                     Tomato Aux Croutons              13
# 4                                         Onion Au Gratin              41
# 5                                              St Emilion              66
# 7                                                Radishes            3262
# 8                                  Chicken With Rice Soup              48
# 9                                          Cup Clam Broth              14
# 10                        Cream of New Asparagus Croutons               2
# 11                                     Clear Green Turtle             157
# 12                            Striped Bass Saute Meuniere               2
# 13                                              Anchovies             453
# 14                          Fresh Lobsters in Every Style               4
# 15                                                 Celeri            4246
# 16                                               Pim Olas             145
# 17                                                 Caviar             505
# 30                   1                  1901           1901          0.00
# 31                 238                  1900           1987          0.00
# ...                ...                   ...            ...           ...
# 448222               0  2006-01-01T00:00:00Z           2006          6.00
# 448224               0  2006-01-01T00:00:00Z           2006          3.00
# 448225               0  2006-01-01T00:00:00Z           2006          7.00
# 448228               0  2006-01-01T00:00:00Z           2006          7.00
# 448229               0  2006-01-01T00:00:00Z           2006          7.00
# 451360               0  2003-01-01T00:00:00Z           2003           NaN
# 451361               0  2003-01-01T00:00:00Z           2003           NaN
# 465520               1                  1909           1909           NaN
# 465524               1                  1909           1909           NaN
# 477196               1                  1909           1909           NaN
# 477197               1                  1909           1909           NaN
# 477198               1                  1909           1909           NaN
# 486409               2                  1909           1913           NaN
# 489914               1                  1869           1869           NaN
# 489915               1                  1869           1869           NaN
# 489916               1                  1869           1869           NaN
# 489917               1                  1869           1869           NaN
# 489918               1                  1869           1869           NaN
# 489919               1                  1869           1869           NaN
# 489920               1                  1869           1869           NaN
# 489921               1                  1869           1869           NaN
# 489922               1                  1869           1869           NaN
# 489925               1                  1869           1869           NaN
# 500328               1  2003-01-01T00:00:00Z           2003           NaN
# 500330               1  2003-01-01T00:00:00Z           2003           NaN
# 501951               1                  1909           1909           NaN
# 501952               1                  1909           1909           NaN
# 501953               1                  1909           1909           NaN
# 501954               1                  1909           1909           NaN
# 501956               1                  1909           1909           NaN
#
#         highest_price                                      name_modified  \
# id
# 1                0.40                         consomme printaniere royal
# 2                0.80                                      chicken gumbo
# 3                0.40                                tomato aux croutons
# 4                1.00                                    onion au gratin
# 5               18.00                                         st emilion
# 7               25.00                                           radishes
# 8                0.60                             chicken with rice soup
# 9                0.40                                     cup clam broth
# 10               0.00                    cream of new asparagus croutons
# 11              60.00                                 clear green turtle
# 12               0.00                        striped bass saute meuniere
# 13              30.00                                          anchovies
# 14               0.00                      fresh lobsters in every style
# 15              50.00                                             celeri
# 16              35.00                                           pim olas
# 17              75.00                                             caviar
# 18              50.00                                           sardines
# 19               0.20                                      india chutney
# 20              10.00                                            pickles
# 21               0.30                                    english walnuts
# 22               1.00                                  pate de fois gras
# 23               5.00                                            pommard
# 24               0.00                         brook trout mountain style
# 25               0.75                            whitebait sauce tartare
# 26               0.90                                         clam juice
# 27              35.00                                            oysters
# 28               2.50                             claremont planked shad
# 29               4.00                         g h mumm & co 's extra dry
# 30               0.00                                cerealine with milk
# 31              15.00                                     sliced bananas
# ...               ...                                                ...
# 448222           6.00                                     pot of pickles
# 448224           3.00                        duck egg with tuna bottarga
# 448225           7.00                                              chard
# 448228           7.00                                      roasted beets
# 448229           7.00                                      broccoli rabe
# 451360            NaN  poached pears burnt caramel ice cream chocolat...
# 451361            NaN  quail and pheasant pie wild rice with walnuts ...
# 465520            NaN                                   canape st martin
# 465524            NaN            calf sweetbreads larded a la rothschild
# 477196            NaN                    spanish fries in crumbs raifort
# 477197            NaN                                   french cream pie
# 477198            NaN                                 chantilly meringue
# 486409            NaN                                      cheese straws
# 489914            NaN                          lait au riz d'amande liì©
# 489915            NaN               mayonnaise de homard ìû la belle vue
# 489916            NaN                        pain de gibier ìû la gelì©e
# 489917            NaN       chaufroid de cailles ìû la moderne sur socle
# 489918            NaN                 suprì»me de poulet ìû la pompadour
# 489919            NaN  cotelettes d'agneau ìû l'impì©ratrice purì©e a...
# 489920            NaN                    faisans et dindes rì«tis salade
# 489921            NaN                        gelì©e aux vin de champagne
# 489922            NaN                    pouding de fraises ìû la sultan
# 489925            NaN                           nougats ìû la parisienne
# 500328            NaN            wì¦lffer estate reserve chardonnay 2000
# 500330            NaN                wì¦lffer estate reserve merlot 2000
# 501951            NaN                  baked black bass stuffed chambord
# 501952            NaN               stuffed young turkey cranberry sauce
# 501953            NaN                roast ribs of prime beef demi glace
# 501954            NaN                                 new century punchs
# 501956            NaN                     roast squab barde en croustade
#
#                                               fingerprint
# id
# 1                                consommeprintaniereroyal
# 2                                            chickengumbo
# 3                                       auxcroutonstomato
# 4                                           augratinonion
# 5                                               emilionst
# 7                                                radishes
# 8                                     chickenricesoupwith
# 9                                            brothclamcup
# 10                            asparaguscreamcroutonsnewof
# 11                                       cleargreenturtle
# 12                               bassmeunieresautestriped
# 13                                              anchovies
# 14                              everyfreshinlobstersstyle
# 15                                                 celeri
# 16                                                olaspim
# 17                                                 caviar
# 18                                               sardines
# 19                                           chutneyindia
# 20                                                pickles
# 21                                         englishwalnuts
# 22                                         defoisgraspate
# 23                                                pommard
# 24                                brookmountainstyletrout
# 25                                  saucetartarewhitebait
# 26                                              clamjuice
# 27                                                oysters
# 28                                   claremontplankedshad
# 29                                      codryextraghmumms
# 30                                      cerealinemilkwith
# 31                                          bananassliced
# ...                                                   ...
# 448222                                       ofpicklespot
# 448224                            bottargaduckeggtunawith
# 448225                                              chard
# 448228                                       beetsroasted
# 448229                                       broccolirabe
# 451360     burntcaramelchocolatecreamicepearspoachedsauce
# 451361  andcranberriespheasantpiequailricewalnutswildwith
# 465520                                     canapemartinst
# 465524                 acalflalardedrothschildsweetbreads
# 477196                        crumbsfriesinraifortspanish
# 477197                                     creamfrenchpie
# 477198                                  chantillymeringue
# 486409                                       cheesestraws
# 489914                                amandeaudlaitliìriz
# 489915                     belledehomardlamayonnaisevueìû
# 489916                              deegelìgibierlapainìû
# 489917              cailleschaufroiddelamodernesoclesurìû
# 489918                       delamepompadourpouletsuprììû
# 489919  agneauauxchampignonscotelettesdeimpìlpurìratri...
# 489920                         dindesetfaisansrìsaladetis
# 489921                             auxchampagnedeegelìvin
# 489922                         defraiseslapoudingsultanìû
# 489925                              lanougatsparisienneìû
# 500328                 2000chardonnayestatelfferreservewì
# 500330                     2000estatelffermerlotreservewì
# 501951                      bakedbassblackchambordstuffed
# 501952                   cranberrysaucestuffedturkeyyoung
# 501953                      beefdemiglaceofprimeribsroast
# 501954                                   centurynewpunchs
# 501956                         bardecroustadeenroastsquab
#
# [2843 rows x 9 columns]

# %% [markdown]
# With this information, we can create a normalized graph:

# %%
normed = [year_series[date_year]/menu_total_series[date_year].astype(float) for date_year in year_series.index.tolist()]
pd.Series(normed, index=year_series.index).plot(figsize=(20,10))

# %% [markdown]
# I hope this notebook demonstrates some ways to use the data analysis tools provided by Pandas in the service of curating data from *What's On the Menu?*
